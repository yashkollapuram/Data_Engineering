# %% [raw]
# A loop in Python is a technique for repeatedly executing a block of code until a specified condition is met or all items in a sequence have been processed.

# %%
for i in range(3):
    print("Hello")
# Out:
# Hello
# Hello
# Hello

# %% [raw]
# In this example, the loop repeatedly executes the print("Hello") statement three times.

# %% [raw]
# A loop consists of:
#
# 1) A repeated action (the code inside the loop).
# 2) A condition or sequence that determines how many times the action should be repeated.

# %% [raw]
# For Loop:
# A for loop is used to execute a block of code repeatedly by iterating over a sequence (such as a list, string or range). A for loop is commonly used when the number of iterations is known or when you want to process every item in a sequence.
#
# Syntax:
# for variable in sequence:
#     # code to execute
#
# 1) variable stores the current item from the sequence.
# 2) sequence is the collection being traversed.
# 3) The indented code block runs once for each item.

# %%
fruits = ["apple", "banana", "mango"]

for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# mango

# %% [markdown]
# The loop visits each item in the list one by one and prints it.

# %%
numbers = [5, 10, 15]

for i in range(len(numbers)):
    print(numbers[i])
# Out:
# 5
# 10
# 15

# %% [raw]
# How it works:
#
# len(numbers) is 3 because there are 3 items in the list.
# range(3) generates 0, 1, 2.
# numbers[0] → 5
# numbers[1] → 10
# numbers[2] → 15
#
# So the loop prints each element of the list one by one.

# %% [raw]
# Reversing the string:
# Reversing a string means arranging the characters of a string in the opposite order, so that the last character becomes the first and the first character becomes the last.

# %%
S = 'Jordan'
X = ' '
for i in range(len(S)):
    X = S[i] + X
    print(X)
# Out:
# J
# oJ
# roJ
# droJ
# adroJ
# nadroJ

# %% [raw]
# Step 1: Initialize variables
# S stores the string "Jordan".
# X starts as an empty string "".
#
# Step 2: Determine the loop range
# len(s) - "Jordan" has 6 characters
#
# range(len(S)) = range(6)
# i = 0, 1, 2, 3, 4, 5
#
# Iteration 1 (i = 0)
# X = S[0] + X
# S[0] is "J"
# X is ""
#
# X = "J" + ""
# X = "J"
#
# Iteration 2 (i = 1)
# X = S[1] + X
# S[1] is "o"
# X is "J"
#
# X = "o" + "J"
# X = "oJ"

# %% [raw]
# Assignment: Reversing the string
# i) Same order & ii) Reverse order

# %%
name = "Michael"

for i in range(len(name)):
    print(name[i])
# Out:
# M
# i
# c
# h
# a
# e
# l

# %% [raw]
# Here:
#
# 1) len(name) is 7
# 2) range(len(name)) generates indices 0, 1, 2, 3, 4, 5, 6
# 3) name[i] accesses each character at those positions in order.

# %%
name = "Michael"

for i in range(len(name) - 1, -1, -1):
    print(name[i])
# Out:
# l
# e
# a
# h
# c
# i
# M

# %% [raw]
# Here:
#
# 1) len(name) is 7
# 2) len(name) - 1 is 6 (the index of the last character)
# 3) range(6, -1, -1) generates the indices: 6, 5, 4, 3, 2, 1, 0

# %% [raw]
# While Loop:
# A while loop will keep iterating till the condition is satisfied.

# %%
count = 1

while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [raw]
# How it works:
# 1) Check the condition (count <= 5).
# 2) If it's True, execute the loop body.
# 3) Update the variable (count += 1).
# 4) Repeat until the condition becomes False.

# %% [raw]
# range() is a built-in function used to generate a sequence of numbers, commonly used in loops. Add "+1" to include the last number as well, with this the range becomes inclusive.

# %% [raw]
# Break Statement:
# Immediately exits the loop entirely.

# %%
for i in range(5):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
i = 0
while i < 5:
    if i == 3:
        break
    print(i)
    i += 1
# Out:
# 0
# 1
# 2

# %% [raw]
# Continue Statement:
# Skips the rest of the current iteration and moves to next iteration.

# %%
for i in range(5):
    if i == 2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4

# %%
i = 0
while i < 5:
    i += 1
    if i == 2:
        continue
    print(i)
# Out:
# 1
# 3
# 4
# 5

# %% [raw]
# Container: A container is any data type that can store multiple values or elements.
# Ex: String, list, Tuple

# %% [raw]
# String: A string is a sequence (container) of characters.
# string = "Hello"
#
# Print(string): Used to display the string
# string = "Hello"
# print(string)
#
# Output: Hello

# %% [raw]
# \n: It helps creating a new line.

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %% [raw]
# len(): Returns the number of characters in a string.

# %%
string = "Hello"
print(len(string))
# Out:
# 5

# %% [raw]
# Index(): Used to find the position of a character or substring.

# %%
string = "Hello"
print(string.index("e"))
# Out:
# 1

# %% [raw]
# Slicing: Slicing is a way to extract parts of sequences such as strings, lists and ranges.
# Syntax: sequence[start:stop:step]
#
# 1) start: index where slicing begins (inclusive)
# 2) stop: index where slicing ends (exclusive)
# 3) step: interval between elements

# %%
numbers = [10, 20, 30, 40, 50, 60]

# %%
numbers[1:4]
# Out:
# [20, 30, 40]

# %% [raw]
# Upper limit: This is the last index NOT included.

# %%
numbers[:4]
# Out:
# [10, 20, 30, 40]

# %% [raw]
# starts from beginning and goes up to index 4 (but NOT include it).

# %% [raw]
# Lower limit: This is the first index included in the result.

# %%
numbers[2:]
# Out:
# [30, 40, 50, 60]

# %% [raw]
# starts at index 2 and include everything from there onwards.

# %% [raw]
# Step size: It controls how many positions Python moves forward each time it picks an element.
# In this below example it takes every 3rd element from the list starting from the beginning.

# %%
numbers[::3]
# Out:
# [10, 40]

# %% [raw]
# Negative indices: Negative indices let you access elements from the end of a sequence instead of the beginning.

# %%
numbers[-1]
# Out:
# 60

# %%
numbers[-3:]
# Out:
# [40, 50, 60]

# %%
numbers[:-2]
# Out:
# [10, 20, 30, 40]

# %% [raw]
# Concatenate Strings: Concatenating strings means joining two or more strings together into one.

# %%
a = "Hello"
b = "World"

result = a + " " + b
print(result)
# Out:
# Hello World

# %%
Location

# %%
fruits = ["apple", "banana", "cherry"]

print(fruits.index("banana"))
# Out:
# 1

# %% [raw]
# expandtabs(): Replaces tab characters (\t) with spaces.

# %%
text = "Hello\tWorld"
print(text.expandtabs(4))
# Out:
# Hello   World

# %% [raw]
# isalnum(): Returns True if all characters are letters or numbers (no spaces or symbols).

# %%
"abc123".isalnum()
# Out:
# True

# %%
"abc 123".isalnum()
# Out:
# False

# %% [raw]
# isalpha(): Returns True if all characters are letters only.

# %%
"Python".isalpha()
# Out:
# True

# %% [raw]
# islower(): Checks if all letters are lowercase (ignores non-letters).

# %%
"hello".islower()
# Out:
# True

# %% [raw]
# isupper(): Checks if all letters are uppercase.

# %%
"HELLO".isupper()
# Out:
# True

# %% [raw]
# isspace(): Returns True if all characters are whitespace (spaces, tabs, newline).

# %%
"   ".isspace()
# Out:
# True

# %% [raw]
# istitle(): Checks if each word starts with a capital letter.

# %%
"Hello World".istitle()
# Out:
# True

# %% [raw]
# endswith(): Checks if a string ends with a specific substring.

# %%
"report.pdf".endswith(".pdf")
# Out:
# True

# %% [raw]
# Built-in Regular Expressions:
# Regular Expressions (regex) are patterns used to match, search and manipulate text based on rules rather than fixed strings.

# %% [raw]
# split(): split() divides a string into a list of parts based on a delimiter.
# Syntax: string.split(separator, maxsplit)

# %%
text = "apple,banana,grape"
print(text.split(","))
# Out:
# ['apple', 'banana', 'grape']

# %% [raw]
# Partition(): partition() splits a string into exactly 3 parts:
#
# 1) part before separator
# 2) the separator itself
# 3) part after separator
#
# Syntax: string.partition(separator)

# %%
text = "name=John"
print(text.partition("="))
# Out:
# ('name', '=', 'John')
